# %%
import spotipy
import spotipy.util as util
import pandas as pd
import os
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv

load_dotenv()
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')

# %%
client_credentials_manager = SpotifyClientCredentials(
    client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def extract_user_playlist(url):
    # Split the url and use Spotipy to retrieve the track information for each song in the playlist
    playlist_url = url.split("/")[4].split("?")[0]
    playlist_tracks = sp.playlist_tracks(playlist_url)

    # For loop to extract the necessary track information
    track_ids = []
    track_titles = []
    track_artist = []
    track_album_art = []
    track_album_url = []

    for track in playlist_tracks['items']:
        track_ids.append(track['track']['id'])
        track_titles.append(track['track']['name'])
        track_album_art.append(track['track']['album']['images'][2]['url'])
        track_album_url.append(track['track']['album']['external_urls']['spotify'])
        artist_list = []
        for artist in track['track']['artists']:
            artist_list.append(artist['name'])
        track_artist.append(artist_list[0])

    # Create a dataframe from the track_ids to bring in features
    features = sp.audio_features(track_ids)

    features_df = pd.DataFrame(data=features, columns=features[0].keys())
    features_df['title'] = track_titles
    features_df['artist'] = track_artist
    features_df['album_art'] = track_album_art
    features_df['album_url'] = track_album_url
    features_df = features_df[['artist','title','album_url','album_art','id','danceability','energy','loudness','speechiness','acousticness','liveness','valence']]
    
    return features_df

# %%
user_playlist = extract_user_playlist(
    'https://open.spotify.com/playlist/5DryjHx6o4EWrGvIX33rnq?si=a01b40825c8f402f')

user_playlist.head()
# Out:
#        artist                    title  \
# 0    Gorillaz           Feel Good Inc.
# 1  Mac Miller   Weekend (feat. Miguel)
# 2  Mac Miller       Come Back to Earth
# 3  Hotel Ugly  Shut up My Moms Calling
# 4  Kanye West           All Falls Down
#
#                                            album_url  \
# 0  https://open.spotify.com/album/0bUTHlWbkSQysoM...
# 1  https://open.spotify.com/album/2Tyx5dLhHYkx6ze...
# 2  https://open.spotify.com/album/5wtE5aLX5r7jOos...
# 3  https://open.spotify.com/album/4qVzNqB4cskFInY...
# 4  https://open.spotify.com/album/3ff2p3LnR6V7m6B...
#
#                                            album_art                      id  \
# 0  https://i.scdn.co/image/ab67616d0000485119d85a...  0d28khcov6AiegSCpG5TuT
# 1  https://i.scdn.co/image/ab67616d00004851ee0f38...  6GnhWMhgJb7uyiiPEiEkDA
# 2  https://i.scdn.co/image/ab67616d00004851175c57...  01z2fBGB8Hl3Jd3zXe4IXR
# 3  https://i.scdn.co/image/ab67616d000048514e9657...  3hxIUxnT27p5WcmjGUXNwx
# 4  https://i.scdn.co/image/ab67616d000048512892dd...  2cYZpcIV39X48RnOFM7w2V
#
#    danceability  energy  loudness  speechiness  acousticness  liveness  \
# 0         0.818   0.705    -6.679       0.1770       0.00836     0.613
# 1         0.843   0.435    -8.442       0.1780       0.47000     0.147
# 2         0.272   0.238   -12.148       0.0349       0.89000     0.275
# 3         0.485   0.409   -10.711       0.1010       0.32500     0.103
# 4         0.643   0.717    -4.876       0.5060       0.18400     0.152
#
#    valence
# 0    0.772
# 1    0.190
# 2    0.119
# 3    0.376
# 4    0.460

# %%
for row in user_playlist.iterrows():
    print(
        f"{row[1]['artist']} - {row[1]['title']} - {row[1]['album_art']} - {row[1]['id']}")
# Out:
# Gorillaz - Feel Good Inc. - https://i.scdn.co/image/ab67616d0000485119d85a472f328a6ed9b704cf - 0d28khcov6AiegSCpG5TuT
# Joey Bada$$ - Zipcodes - https://i.scdn.co/image/ab67616d00004851aacc3ddf3bfa01f4bd44cacc - 2S3PBAzoPAxnmdOtdEuaLW
# Mac Miller - Willie Dynamite - https://i.scdn.co/image/ab67616d000048512e8e9d480a55d914e1c5ff3b - 4D8eHHa0MPGGh4EJj7lMpS
# Mac Miller - Best Day Ever - https://i.scdn.co/image/ab67616d00004851caed626d0cb2f60220977db8 - 56XhZKFVFeylLeAELp6pdE
# Mac Miller - BDE Bonus - https://i.scdn.co/image/ab67616d00004851caed626d0cb2f60220977db8 - 4vbCuMBvSN4jqOX4ypQcbz
# Mac Miller - Earth - https://i.scdn.co/image/ab67616d000048514052e974e7fc03fa49770986 - 7yPGXCaeIr1ofJoqp3LeKF
# Marlon Craft - Can't Call It - https://i.scdn.co/image/ab67616d0000485194e8a584cd4aa81d493e7a1f - 5bNSWi44QfD9lTdQyDngu6
# YGTUT - Living On the Sun - https://i.scdn.co/image/ab67616d00004851bb3c66fc494aedb1e2019805 - 2o2i2bSeg92SdRSJ9cc736
# YGTUT - Live from Chattanooga - https://i.scdn.co/image/ab67616d00004851bb3c66fc494aedb1e2019805 - 4xC00vwRyE2YVdlOJuKAAB
# YGTUT - G35 - https://i.scdn.co/image/ab67616d000048510e679e7602f926b689744aee - 12whPvsw1oxuuwlD27mTeb
# Trippie Redd - Forever Ever - https://i.scdn.co/image/ab67616d00004851d959c12f4de683c39a1bafe3 - 2c3qwFINQyRGwyqI97UQiA
# Young Thug - Day Before (with Mac Miller) - https://i.scdn.co/image/ab67616d00004851f8d415dab5ed7e3747bd38dd - 2eYsZ2JEq63Q0S8LQVscBm
# Future - Too Comfortable - https://i.scdn.co/image/ab67616d00004851935d8d5369bc55e74a39303e - 0biVzpdI2z0vAxwfU9xuuA

# %%
# Filtering through the data to see what we need to pull
playlist_tracks = sp.playlist_tracks(
    'https://open.spotify.com/playlist/5DryjHx6o4EWrGvIX33rnq?si=d566f40322a3430e')
playlist_tracks['items'][0]['track']['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AA28KZvwAUcZuOKwyblJQ'},
#    'href': 'https://api.spotify.com/v1/artists/3AA28KZvwAUcZuOKwyblJQ',
#    'id': '3AA28KZvwAUcZuOKwyblJQ',
#    'name': 'Gorillaz',
#    'type': 'artist',
#    'uri': 'spotify:artist:3AA28KZvwAUcZuOKwyblJQ'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'ET',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TR',
#   'TT',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/0bUTHlWbkSQysoM3VsWldT'},
#  'href': 'https://api.spotify.com/v1/albums/0bUTHlWbkSQysoM3VsWldT',
#  'id': '0bUTHlWbkSQysoM3VsWldT',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27319d85a472f328a6ed9b704cf',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0219d85a472f328a6ed9b704cf',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485119d85a472f328a6ed9b704cf',
#    'width': 64}],
#  'name': 'Demon Days',
#  'release_date': '2005-05-23',
#  'release_date_precision': 'day',
#  'total_tracks': 15,
#  'type': 'album',
#  'uri': 'spotify:album:0bUTHlWbkSQysoM3VsWldT'}

# %%
'https://open.spotify.com/track/0d28khcov6AiegSCpG5TuT'
